# %%
import numpy as np
import pandas as pd
import glob


#from matplotlib import pyplot as plt
#%matplotlib inline

# %%
l = [pd.read_csv(file, delimiter=' ', header=None) for file in glob.glob('./../Data/train_db/0001*')]
len(l)
train_raw = pd.concat(l, axis=0)
train_raw = train_raw.iloc[:,2:-1]
# Out:
# 270

# %%
train_raw.shape
# Out:
# (270, 403)

# %%
train_raw
# Out:
#          2         3         4         5         6         7         8    \
# 0   1.465550  1.622700 -0.637980 -0.216312  1.390040  1.000050 -0.050596
# 0   1.385560  1.065890 -0.223668 -1.536550 -0.322198  0.849226 -2.020030
# 0   1.534610  1.516170 -0.671719  0.816759  0.430839  0.348457  0.025342
# 0   1.844870  1.411380  0.029660  1.903740 -1.215960  0.602002  0.159688
# 0   0.984934  1.415890 -0.336062 -0.807787  0.413207 -0.299780  0.640166
# 0   0.791058  1.068040  0.740688 -1.080890  0.533408 -0.423472 -1.500220
# 0   1.395450  1.295360  0.804296 -0.548172 -0.444467  0.737827  1.241650
# 0   1.588540  1.264420  0.050543 -0.594350  1.126440  1.118670  0.994021
# 0   1.582040  1.463920  0.999639 -0.524431  0.497493  1.298490  3.964100
# 0   1.656120  1.741680 -1.379050  0.455761 -0.122774  0.862495  0.904091
# 0   1.147980  0.838120  1.885080  0.393981 -0.368711  1.695380  0.012614
# 0   1.812890  1.417150 -1.107440  0.843232 -0.023907 -0.075202  1.109820
# ...
